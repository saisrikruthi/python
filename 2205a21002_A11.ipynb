# %% [markdown]
# <a href="https://colab.research.google.com/github/saisrikruthi/python/blob/main/2205a21002_A11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
students={
    "Roll_no":[101,102,103,104,105],
    "Telugu":[35,98,43,65,78],
    "English":[87,45,98,65,34],
    "Hindi":[45,26,78,45,67],
    "Maths":[45,56,67,78,89],
    "Science":[23,34,45,56,76],
    "Social":[32,43,54,65,67]
}
data=pd.DataFrame(students)
hall_ticket_no=int(input("enter hall ticket no."))
ind=data[data["Roll_no"]==hall_ticket_no].index

score_card=data.loc[[ind[0]]]
score_card.pop("Roll_no")
percentage=score_card.loc[ind[0]].sum()*100/600
fail=score_card[score_card<35].count()
no_of_fail_sub=fail.sum()
failed_sub=fail[fail==1].index
if(no_of_fail_sub>0):
  print("status:fail")
  print("failed_sub:",failed_sub)
else:
  print("status:pass")
  print("pass percentage:",percentage)


score_card
# Out:
# enter hall ticket no.102
# status:fail
# failed_sub: Index(['Hindi', 'Science'], dtype='object')
#    Telugu  English  Hindi  Maths  Science  Social
# 1      98       45     26     56       34      43
