# %% [markdown]
# <a href="https://colab.research.google.com/github/saisrikruthi/python/blob/main/2205A21002_A10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks=np.array([[[101,35,98,43,65,78,96],

[102,87,45,98,65,34,78],

[103,45, 26,78,45,67,34],

[104,45,56,67,78,89,90],

[105,23,34,45,56,76,87]],

[[101,53,89,43,56,87,69],

[102,78,54,89,56,43,87],

[103,54,62,87,54,76,43],

[104,35,65,76,87,98,9],

[105,32,43,54,65,67,78]]])

stud=marks.shape[1]

sem=marks.shape[0]

Hall_Ticket_No=int(input("enter hall ticket no."))

semester=int(input("enter semester no."))
for i in range(sem):
  if(semester==i+1):
    break

index_sem=i

for j in range(stud):
  if(Hall_Ticket_No==marks [index_sem,j,0]):
    break

index_stud=j

marks_percentage=np.sum(marks [index_sem, index_stud, 1:marks.shape[2]])*100/600

count=0

failed_sub=[]

for i in range(1,marks.shape[2 ]):

  if(marks [index_sem, index_stud, i] <40):

     count=count+1

failed_sub.append(i)
print("====================")
print("   SR University   ")

print("    Score Card   ")

print("=====================")


print("Roll ,Hall_Ticket_No")

print("Semester:", semester)

print("Subject1:", marks [index_sem, index_stud,1])

print("Subject2:", marks [index_sem, index_stud,2])

print("Subject3:", marks [index_sem, index_stud, 3])

print("Subject4:", marks [index_sem, index_stud, 4])

print("Subject5:", marks [index_sem, index_stud, 5])

print("Subject6:", marks [index_sem, index_stud, 6])
print("===========================")
print("       Results Status      ")
print("===========================")
if(count>0):

  print("Fail")

  print("Failed Subjects:",)

  for i in range(len(failed_sub)):

    if(failed_sub[i]==1):

      print("Subject1")

    if(failed_sub[i]==2):

      print("Subject2")

    if(failed_sub[i]==3):

      print("Subject3")

    if(failed_sub[i]==4):

     print("Subject4")

    if(failed_sub[i]==5):

      print("Subject5")

    if(failed_sub[i]==6):

      print("Subject6")

else:

    print("Pass")
    print("Percentage of marks:", np.round(marks_percentage))
print("==========================")
# Out:
# enter hall ticket no.104
# enter semester no.1
# ====================
#    SR University
#     Score Card
# =====================
# Roll ,Hall_Ticket_No
# Semester: 1
# Subject1: 45
# Subject2: 56
# Subject3: 67
# Subject4: 78
# Subject5: 89
# Subject6: 90
# ===========================
#        Results Status
# ===========================
# Pass
# Percentage of marks: 71.0
# ==========================
